# %%
import pandas as pd

# %%
import os 
os.chdir('./nishika_conpe/hand_apartment')
os.getcwd()
# Out:
# '/Users/hayashidanaoki/jupyter_home/nishika_conpe/hand_apartment'

# %%
import glob

# %% [markdown]
# # データ読み取り

# %%
train_df = pd.DataFrame()
for i in glob.glob('./input/train/*.csv'):
    temp = pd.read_csv(i)
    train_df = train_df.append(temp)

# %%
test_df = pd.read_csv('./input/test.csv')

# %% [markdown]
#  # 統計量

# %%
train_df.head()
# Out:
#         ID        種類  地域  市区町村コード 都道府県名   市区町村名   地区名 最寄駅：名称 最寄駅：距離（分）   間取り  \
# 0  1117225  中古マンション等 NaN     1213   北海道    苫小牧市  新中野町    苫小牧        25  ３ＬＤＫ
# 1  1001180  中古マンション等 NaN     1101   北海道  札幌市中央区  北２条西  西２８丁目         8  ４ＬＤＫ
# 2  1099061  中古マンション等 NaN     1207   北海道     帯広市  西３条南     帯広         2  ２ＬＤＫ
# 3  1039968  中古マンション等 NaN     1105   北海道  札幌市豊平区  平岸２条    南平岸         6  ３ＬＤＫ
# 4  1072923  中古マンション等 NaN     1202   北海道     函館市   梁川町    五稜郭   30分?60分  ２ＬＤＫ
#
#    ... 前面道路：方位  前面道路：種類  前面道路：幅員（ｍ）    都市計画 建ぺい率（％） 容積率（％）        取引時点   改装  \
# 0  ...     NaN      NaN         NaN   準工業地域    60.0  200.0  2018年第３四半期  未改装
# 1  ...     NaN      NaN         NaN  近隣商業地域    80.0  300.0  2018年第３四半期  未改装
# 2  ...     NaN      NaN         NaN    商業地域    80.0  500.0  2016年第２四半期  未改装
# 3  ...     NaN      NaN         NaN  近隣商業地域    80.0  300.0  2018年第４四半期  改装済
# 4  ...     NaN      NaN         NaN    商業地域    80.0  400.0  2015年第１四半期  未改装
#
#    取引の事情等  取引価格（総額）_log
# ...

# %%
train_df.columns
# Out:
# Index(['ID', '種類', '地域', '市区町村コード', '都道府県名', '市区町村名', '地区名', '最寄駅：名称',
#        '最寄駅：距離（分）', '間取り', '面積（㎡）', '土地の形状', '間口', '延床面積（㎡）', '建築年', '建物の構造',
#        '用途', '今後の利用目的', '前面道路：方位', '前面道路：種類', '前面道路：幅員（ｍ）', '都市計画', '建ぺい率（％）',
#        '容積率（％）', '取引時点', '改装', '取引の事情等', '取引価格（総額）_log'],
#       dtype='object')

# %% [markdown]
#  ### データ件数

# %%
print('学習データ:' + str(len(train_df)))
print('テストデータ:' + str(len(test_df)))
# Out:
# 学習データ:651975
# テストデータ:17894

# %% [markdown]
#  ### 項目別バリエーション

# %%
for i in train_df.columns:
    if i == 'ID':
        pass
    else:
        print(train_df[['ID',i]].groupby([i]).count())
# Out:
#               ID
# 種類
# 中古マンション等  651975
# Empty DataFrame
# Columns: [ID]
# Index: []
#            ID
# 市区町村コード
# 1101     5893
# 1102     2272
# 1103     1366
# 1104     1796
# 1105     2957
# ...       ...
# 46218      78
# 47201    1410
# 47208     271
# 47211     156
# 47213      21
#
# [618 rows x 1 columns]
#            ID
# 都道府県名
# 三重県      1730
# 京都府     15469
# 佐賀県       603
# 兵庫県     39879
# 北海道     22062
# 千葉県     33976
# 和歌山県      795
# 埼玉県     39459
# 大分県      2701
# 大阪府     73594
# 奈良県      4902
# 宮城県     10125
# 宮崎県      1184
# 富山県       921
# 山口県      1877
# 山形県       528
# 山梨県       543
# 岐阜県      1361
# 岡山県      2506
# 岩手県      1311
# 島根県       299
# 広島県      5445
# 徳島県       601
# 愛媛県      1971
# 愛知県     31268
# 新潟県      3527
# 東京都    195230
# 栃木県      1917
# 沖縄県      1858
# 滋賀県      3417
# 熊本県      2439
# 石川県      1702
# 神奈川県    93198
# 福井県       520
# 福岡県     30606
# 福島県      1844
# 秋田県       761
# 群馬県      1685
# 茨城県      3326
# 長崎県      1759
# 長野県      1204
# ...

# %% [markdown]
# ## 神奈川に絞ってみる

# %%
kanagawa_df = pd.read_csv('./input/train/14.csv')

# %%
kanagawa_df.sort_values(by='取引価格（総額）_log').to_csv('./output/kanagawa_value_sort.csv')
